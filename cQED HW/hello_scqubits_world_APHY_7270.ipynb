# %%
import numpy as np
import scqubits

# %% [markdown]
# Don't worry about understanding any of the plots below, we'll cover material like this in due time. For now, just confirm that each of these cells can run without giving an error

# %%
fluxonium = scqubits.Fluxonium(EJ = 12,
                               EC = 4,
                               EL = 0.3,
                               flux = 0.,
                               cutoff = 110)

fluxonium.plot_wavefunction(which=[0,1,2,3,4])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %%
transmon = scqubits.Transmon(EJ = 20,EC = 0.1,ng=0.,ncut=100)

transmon.plot_wavefunction(which=[0,1,2,3,4])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %%
spectrum_vs_flux = fluxonium.get_spectrum_vs_paramvals('flux',np.linspace(-0.05,0.05,100),evals_count=4)
spectrum_vs_flux.plot_evals_vs_paramvals(which = [1,2])
# Out:
# Spectral data:   0%|          | 0/100 [00:00<?, ?it/s]
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\Phi_{ext}/\\Phi_0$', ylabel='energy [GHz]'>)
